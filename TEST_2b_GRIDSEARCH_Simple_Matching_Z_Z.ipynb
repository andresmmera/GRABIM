# %%
# GRABIM TEST
# %load_ext autoreload
# %autoreload 2
import numpy as np

import GRABIM as GRABIM


# Plot (external libraries)
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import Legend, LegendItem
from bokeh.models import Arrow, NormalHead
from bokeh.models import ColumnDataSource, LabelSet, Text
output_notebook()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1143">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### SETUP
#
# Matching between two complex impedances, constant vs freq

# %%
# Problem input
f1 = 400e6; # [Hz] Start frequency
f2 = 1000e6; # [Hz] End frequency
m = 10; # Number of frequency samples
freq = np.linspace(f1, f2, m);

ZS = (20-10j)*np.ones(m, dtype=complex); # [Ohm] Source impedance
ZL = (120+30j)*np.ones(m, dtype=complex); # [Ohm] Load impedance

# %%
# GRID SEARCH
code = ['CS', 'LP', 'CS', 'LP', 'CS', 'LP'];
[v_best, RLmax] = GRABIM.GridSearch(ZS, ZL, freq, m, code, 1)
print(v_best)
print("RLmax = ", "{:.2f}".format(RLmax), 'dB')

GRABIM.Plot_S21_S11_dB(ZS, ZL, code, v_best, freq)
# Out:
# [6.14579689e-04 3.09710218e-08 6.14579689e-04 3.09710218e-08
#  6.53435837e-12 1.93811702e-08]
# RLmax =  5.87 dB
#   <div class="bk-root" id="9cf45569-9fb7-4ef5-a0f9-dc79f7eb2cf6" data-root-id="1144"></div>
