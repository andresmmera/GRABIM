# %%
# GRABIM TEST
# %load_ext autoreload
# %autoreload 2
import numpy as np

import GRABIM as GRABIM


# Plot (external libraries)
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import Legend, LegendItem
from bokeh.models import Arrow, NormalHead
from bokeh.models import ColumnDataSource, LabelSet, Text
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# Problem input
f1 = 450e6; # [Hz] Start frequency
f2 = 500e6; # [Hz] End frequency
m = 10; # Number of frequency samples
freq = np.linspace(f1, f2, m);

ZS = 50*np.ones(m, dtype=complex); # [Ohm] Source impedance
ZL = 100*np.ones(m, dtype=complex); # [Ohm] Load impedance

# %%
# GRID SEARCH
code = ['LS', 'CP'];
[v_best, RL] = GRABIM.GridSearch(ZS, ZL, freq, m, code, 1)
print(v_best)
# Out:
# [1.67737523e-08 3.38839110e-12]

# %%
GRABIM.Plot_S21_S11_dB(ZS, ZL, code, v_best, freq)
# Out:
#   <div class="bk-root" id="40769f37-38e5-4ccf-890d-701c136f8b8f" data-root-id="1003"></div>

# %%
GRABIM.Plot_S11_nu(ZS, ZL, code, v_best, freq)
# Out:
#   <div class="bk-root" id="945d0c09-c995-4d7c-8b81-ef66370eaf96" data-root-id="1143"></div>
